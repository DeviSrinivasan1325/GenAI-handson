# %%
import os
import google.generativeai as genai

os.environ["GOOGLE_API_USE_REST"] = "true"

genai.configure(api_key="AIzaSyAyrdNeIWZw9xyukP8p6ZCYUAfLfdC_ahQ")

model = genai.GenerativeModel("models/gemini-2.5-flash")

response = model.generate_content("Give me 3 ideas for app I could build with Gemini APIs")

print(response.text)
# Out:
# Here are 3 ideas for apps you could build using the Gemini APIs, ranging from practical to creative:
#
# ---
#
# ### 1. **Concept Clarity AI: Adaptive Explainer & Learning Coach**
#
# **Idea:** An app that acts as a personalized tutor, explaining complex concepts from any field (science, history, programming, philosophy, etc.) at varying levels of detail and through different analogies, based on user needs.
#
# **How Gemini Helps:**
#
# *   **Multifaceted Explanations:** Gemini can explain a single concept in multiple ways:
#     *   "Explain like I'm 5."
#     *   "Explain it to a college student."
#     *   "Explain it using a sports analogy."
#     *   "Explain the core principles and its implications."
# *   **Interactive Q&A:** Users can ask follow-up questions, and Gemini can provide detailed, context-aware answers to deepen understanding.
# *   **Summarization & Key Takeaways:** For longer texts or topics, Gemini can distill key information and generate concise summaries.
# ...

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAyrdNeIWZw9xyukP8p6ZCYUAfLfdC_ahQ")

for model in genai.list_models():
    print(model.name, model.supported_generation_methods)
# Out:
# models/gemini-2.5-flash ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-pro ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-001 ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-lite-001 ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-lite ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-flash-preview-tts ['countTokens', 'generateContent']
# models/gemini-2.5-pro-preview-tts ['countTokens', 'generateContent', 'batchGenerateContent']
# models/gemma-3-1b-it ['generateContent', 'countTokens']
# models/gemma-3-4b-it ['generateContent', 'countTokens']
# ...
